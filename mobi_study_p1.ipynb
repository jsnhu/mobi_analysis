# %%
import sqlite3
import pandas as pd
import os
import glob
import re

# %%
csv_dir = "mobi_csv"
table_name = "rides"

# %%
def standardize_column_string(name: str) -> str:
    # Remove any text within parentheses
    temp = re.sub(r'\([^()]*\)', '', name)
    temp = temp.strip().lower().replace(' ', '_')
    return temp

def standardize_column_names(df: pd.DataFrame) -> pd.DataFrame:
    standardized_columns = [standardize_column_string(col) for col in df.columns]
    df.columns = standardized_columns
    return df

# %%
sample_csv = "mobi_csv/September_2025.csv"
sample_df = pd.read_csv(sample_csv, nrows=5)
sample_df = standardize_column_names(sample_df)
standardized_columns = sample_df.columns.tolist()
# standardized_columns
# ['departure',
#  'return',
#  'bike',
#  'electric_bike',
#  'departure_station',
#  'return_station',
#  'membership_type',
#  'covered_distance',
#  'duration',
#  'departure_temperature',
#  'return_temperature',
#  'stopover_duration',
#  'number_of_stopovers']

# %%
standardized_columns_datatypes = [
    'DATETIME',    # departure
    'DATETIME',    # return
    'INTEGER',    # bike
    'BOOLEAN',    # electric_bike
    'TEXT',    # departure_station
    'TEXT',    # return_station
    'TEXT',    # membership_type
    'INTEGER',    # covered_distance
    'INTEGER', # duration
    'INTEGER',    # departure_temperature
    'INTEGER',    # return_temperature
    'INTEGER', # stopover_duration
    'INTEGER'  # number_of_stopovers
]
standardized_columns_dict = dict(zip(standardized_columns, standardized_columns_datatypes))

# %%
conn = sqlite3.connect("mobi.db")

# %%
csv_files = glob.glob(os.path.join(csv_dir, "*.csv"))

# %%
print(f"Found {len(csv_files)} CSV files in directory '{csv_dir}':")
# Out:
# Found 92 CSV files in directory 'mobi_csv':

# %%
for file in csv_files:
    print(f"Importing file: {file}")
    df = pd.read_csv(file)
    df.to_sql(table_name, conn, if_exists='append', index=False)
# Out:
# Importing file: mobi_csv/May_2022.csv
# Importing file: mobi_csv/July_2019.csv
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[11], line 4
#       2 print(f"Importing file: {file}")
#       3 df = pd.read_csv(file)
# ----> 4 df.to_sql(table_name, conn, if_exists='append', index=False)
#
# File ~/cse6040/mobi/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/cse6040/mobi/.venv/lib/python3.12/site-packages/pandas/core/generic.py:3109, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2911 """
#    2912 Write records stored in a DataFrame to a SQL database.
#    2913
#    (...)   3105 [(1,), (None,), (2,)]
#    3106 """  # noqa: E501
#    3107 from pandas.io import sql
# -> 3109 return sql.to_sql(
#    3110     self,
#    3111     name,
#    3112     con,
#    3113     schema=schema,
#    3114     if_exists=if_exists,
#    3115     index=index,
#    3116     index_label=index_label,
#    3117     chunksize=chunksize,
#    3118     dtype=dtype,
#    3119     method=method,
#    3120 )
#
# File ~/cse6040/mobi/.venv/lib/python3.12/site-packages/pandas/io/sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File ~/cse6040/mobi/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2841, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2831 table = SQLiteTable(
#    2832     name,
#    2833     self,
#    (...)   2838     dtype=dtype,
#    2839 )
#    2840 table.create()
# -> 2841 return table.insert(chunksize, method)
#
# File ~/cse6040/mobi/.venv/lib/python3.12/site-packages/pandas/io/sql.py:1121, in SQLTable.insert(self, chunksize, method)
#    1118     break
#    1120 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1121 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1122 # GH 46891
#    1123 if num_inserted is not None:
#
# File ~/cse6040/mobi/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2537, in SQLiteTable._execute_insert(self, conn, keys, data_iter)
#    2535 def _execute_insert(self, conn, keys, data_iter) -> int:
#    2536     data_list = list(data_iter)
# -> 2537     conn.executemany(self.insert_statement(num_rows=1), data_list)
#    2538     return conn.rowcount
#
# OperationalError: table rides has no column named Bike
